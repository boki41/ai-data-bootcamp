# %% [markdown]
# ## 📊 데이터 분석 보고서
#
# ### 1. 분석 개요
# - 대상: 모두마켓 주문 1,500건 (2025-01 ~ 2025-05), 고객·상품 정보 병합
# - 방법: 3개 테이블 키 검증 후 `m:1` 병합 → 월별 KPI 집계 → 교차표·점유율 분석
#
# ### 2. 핵심 발견
# - 매출이 가장 높았던 달은 **2025-03**였으며(약 20,035,000원), 전월 대비 증감률은 **+17.6%**로 확인됨.
# - 카테고리 중 **패션**, 지역 중 **인천**의 매출 기여가 가장 컸음.
# - 전체 객단가는 약 **60,637원**.
#
# ### 3. 데이터 신뢰성 (반드시 기록)
# - 병합 전 키 검증: 중복 0건, 미매칭 0건 → 행 폭증·조용한 결측 없음.
# - `validate="m:1"` 통과 → 관계 가정(주문:상품 = m:1) 유효.
#
# ### 4. 제언
# - 월별 매출 변동을 보면 2025-03은 구매고객수(326명)와 객단가(61,457원) 둘 다 소폭 상승하며 매출을 견인함. 반면 2025-05는 구매고객수(268명)가 크게 줄며 매출이 감소함 → **고객 유입 감소가 매출 변동의 핵심 원인**으로 보이며, 재구매·유입 채널 강화가 필요.
